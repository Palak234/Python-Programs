# %%
import numpy as np
import pandas as pd
df=pd.read_csv('imdb_data.csv')
df.shape
# Out:
# (3000, 23)

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# 2999  http://www.abductionthefilm.com/  tt1600195                en
#
#                original_title  \
# 2995                  Chasers
# 2996              Vi är bäst!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                overview  popularity  ...  \
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                          spoken_languages    status  \
# 2995      4/22/94   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996      3/28/13   102.0  [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997     10/11/96   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998      1/16/04    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999      9/22/11   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                         title  \
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                Keywords  \
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
# Indexing and Slicing
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
df.iloc[:5,-3:]
# Out:
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970

# %%
df.loc[20:30,['budget','genres','runtime']]
# Out:
#       budget                                             genres  runtime
# 20  80000000  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...    130.0
# 21   4000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...     95.0
# 22         0  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...    116.0
# 23         0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...     92.0
# 24         0  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...     87.0
# 25         0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...     95.0
# 26  10000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...    110.0
# 27  11000000  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...     93.0
# 28   6000000                  [{'id': 16, 'name': 'Animation'}]     84.0
# 29  45000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...     89.0
# 30  13000000  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...    112.0

# %%
df[10:30]
# Out:
#     id                              belongs_to_collection     budget  \
# 10  11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...    1000000
# 11  12  [{'id': 48190, 'name': 'Revenge of the Nerds C...          0
# 12  13                                                NaN   15000000
# 13  14  [{'id': 91698, 'name': 'Chili Palmer Collectio...   53000000
# 14  15                                                NaN  102000000
# 15  16                                                NaN     500000
# 16  17                                                NaN   26000000
# 17  18                                                NaN          0
# 18  19                                                NaN    8000000
# 19  20  [{'id': 9518, 'name': 'The Transporter Collect...   32000000
# 20  21                                                NaN   80000000
# 21  22  [{'id': 9735, 'name': 'Friday the 13th Collect...    4000000
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 23  24                                                NaN          0
# 24  25                                                NaN          0
# 25  26                                                NaN          0
# 26  27                                                NaN   10000000
# 27  28                                                NaN   11000000
# 28  29                                                NaN    6000000
# 29  30                                                NaN   45000000
#
#                                                genres  \
# 10                      [{'id': 18, 'name': 'Drama'}]
# 11                     [{'id': 35, 'name': 'Comedy'}]
# 12                      [{'id': 18, 'name': 'Drama'}]
# 13  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 15  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 16  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 17  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 18  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 19  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 20  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 21  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 23  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 24  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 25  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 26  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 27  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 28                  [{'id': 16, 'name': 'Animation'}]
# 29  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                  homepage    imdb_id original_language  \
# 10                                    NaN  tt0075148                en
# 11                                    NaN  tt0093857                en
# 12          http://www.dreamworks.com/ab/  tt0169547                en
# 13                                    NaN  tt0377471                en
# 14                                    NaN  tt0181689                en
# 15  http://skinningmovie.com/synopsis.htm  tt1129437                sr
# 16                                    NaN  tt0421239                en
# 17                                    NaN  tt1700845                en
# 18                                    NaN  tt1487118                en
# 19                                    NaN  tt0388482                en
# 20                                    NaN  tt0120738                en
# 21                                    NaN  tt0083972                en
# 22    http://www.magnetreleasing.com/vhs/  tt2105044                en
# 23            http://insightthemovie.com/  tt1687277                en
# 24    http://www.blacksheep-themovie.com/  tt0779982                en
# 25                                    NaN  tt0104139                en
# 26                                    NaN  tt0120176                en
# 27                                    NaN  tt1486834                en
# 28                                    NaN  tt0092106                en
# 29                                    NaN  tt0264472                en
#
#                                 original_title  \
# 10                                       Rocky
# 11  Revenge of the Nerds II: Nerds in Paradise
# 12                             American Beauty
# 13                                     Be Cool
# 14                             Minority Report
# 15                                     Šišanje
# 16                                     Red Eye
# 17                         The Invisible Woman
# 18                                 Chalet Girl
# 19                               Transporter 2
# 20                               Lost in Space
# 21                    Friday the 13th Part III
# 22                                       V/H/S
# 23                                     InSight
# 24                                 Black Sheep
# 25                                 Dr. Giggles
# 26                        The Spanish Prisoner
# 27                                     What If
# 28                 The Transformers: The Movie
# 29                              Changing Lanes
#
#                                              overview  popularity  ...  \
# 10  When world heavyweight boxing champion, Apollo...   14.774066  ...
# 11  The members of the Lambda Lambda Lambda frater...   10.543750  ...
# 12  Lester Burnham, a depressed suburban father in...   20.726578  ...
# 13  Disenchanted with the movie industry, Chili Pa...   13.314233  ...
# 14  John Anderton is a top 'Precrime' cop in the l...   20.666063  ...
# 15  Novica is a mathematics champion in a Belgrade...    1.018477  ...
# 16  After attending the funeral of her grandmother...    6.336927  ...
# 17  In 1857, at the height of his fame and fortune...    4.183558  ...
# 18  While working a job at an exclusive ski resort...    6.496259  ...
# 19  Professional driver Frank Martin is living in ...   11.359659  ...
# 20  The prospects for continuing life on Earth in ...   12.000579  ...
# 21  An idyllic summer turns into a nightmare of un...    7.992290  ...
# 22  When a group of misfits is hired by an unknown...    7.820787  ...
# 23  Kaitlyn, an ER nurse who is tending to a young...    1.323333  ...
# 24  A genetic engineering experiment gone horribly...    7.434577  ...
# 25  In 1957, Evan Rendell flees after his father i...    1.252367  ...
# 26  An employee of a corporation with a lucrative ...    4.305735  ...
# 27  Wallace, a medical school dropout, has been re...   10.841891  ...
# 28  The Autobots must stop a colossal planet-consu...    6.759181  ...
# 29  A rush-hour fender-bender on New York City's c...    7.818620  ...
#
#    release_date runtime                                   spoken_languages  \
# 10     11/21/76   119.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 11      7/10/87    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 12      9/15/99   122.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13       3/4/05   118.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 14      6/20/02   145.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 15      10/6/10    97.0            [{'iso_639_1': 'sr', 'name': 'Srpski'}]
# 16       8/4/05    85.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 17     12/25/13   111.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 18       2/2/11    96.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 19       8/2/05    87.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 20       4/3/98   130.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 21      8/13/82    95.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 22      7/28/12   116.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 23       9/2/11    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 24       9/9/06    87.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 25     10/23/92    95.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 26       9/8/97   110.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 27       9/7/13    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 28       8/8/86    84.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 29       4/7/02    89.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#       status                                            tagline  \
# 10  Released          His whole life was a million-to-one shot.
# 11  Released                                      They're Back!
# 12  Released                                       Look closer.
# 13  Released           Everyone is looking for the next big hit
# 14  Released    The system is perfect until it comes after you.
# 15  Released  Life is sometimes rude game: one mistake can b...
# 16  Released                                 Fear takes flight.
# 17  Released  His greatest story was the one he could never ...
# 18  Released                        How to marry a billionaire.
# 19  Released      The Best In The Business Is Back In The Game.
# 20  Released                             Danger, Will Robinson!
# 21  Released       There's nowhere to hide. We dare you to try.
# 22  Released                         This collection is killer.
# 23  Released                                  Fear what you see
# 24  Released  There are over 40 million sheep in New Zealand...
# 25  Released                  The Doctor is out... of his mind.
# 26  Released                   It's the oldest con in the book.
# 27  Released                 ...being friends has its benefits?
# 28  Released  Beyond good. Beyond evil. Beyond your wildest ...
# 29  Released  An ambitious lawyer, a desperate father, they ...
#
#                                          title  \
# 10                                       Rocky
# 11  Revenge of the Nerds II: Nerds in Paradise
# 12                             American Beauty
# 13                                     Be Cool
# 14                             Minority Report
# 15                                    Skinning
# 16                                     Red Eye
# 17                         The Invisible Woman
# 18                                 Chalet Girl
# 19                               Transporter 2
# 20                               Lost in Space
# 21                    Friday the 13th Part III
# 22                                       V/H/S
# 23                                     InSight
# 24                                 Black Sheep
# 25                                 Dr. Giggles
# 26                        The Spanish Prisoner
# 27                                     What If
# 28                 The Transformers: The Movie
# 29                              Changing Lanes
#
#                                              Keywords  \
# 10  [{'id': 240, 'name': 'underdog'}, {'id': 276, ...
# 11  [{'id': 5801, 'name': 'nerd'}, {'id': 6876, 'n...
# 12  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 13  [{'id': 3605, 'name': 'baseball bat'}, {'id': ...
# 14  [{'id': 476, 'name': 'self-fulfilling prophecy...
# 15  [{'id': 379, 'name': 'skinhead'}, {'id': 7492,...
# 16  [{'id': 1562, 'name': 'hostage'}, {'id': 2250,...
# 17  [{'id': 5565, 'name': 'biography'}, {'id': 180...
# 18  [{'id': 271, 'name': 'competition'}, {'id': 35...
# 19  [{'id': 779, 'name': 'martial arts'}, {'id': 1...
# 20  [{'id': 4379, 'name': 'time travel'}, {'id': 1...
# 21  [{'id': 1889, 'name': 'lake'}, {'id': 5767, 'n...
# 22  [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
# 23                                                NaN
# 24  [{'id': 2658, 'name': 'new zealand'}, {'id': 3...
# 25                                                NaN
# 26  [{'id': 811, 'name': 'dialogue'}, {'id': 2246,...
# 27  [{'id': 10556, 'name': 'male female relationsh...
# 28  [{'id': 4290, 'name': 'toy'}, {'id': 4375, 'na...
# 29  [{'id': 242, 'name': 'new york'}, {'id': 4056,...
#
#                                                  cast  \
# 10  [{'cast_id': 16, 'character': 'Rocky Balboa', ...
# 11  [{'cast_id': 2, 'character': 'Lewis Skolnick',...
# 12  [{'cast_id': 6, 'character': 'Lester Burnham',...
# 13  [{'cast_id': 4, 'character': 'Chili Palmer', '...
# 14  [{'cast_id': 5, 'character': 'Chief John Ander...
# 15  [{'cast_id': 1001, 'character': 'Novica', 'cre...
# 16  [{'cast_id': 1, 'character': 'Lisa Reisert', '...
# 17  [{'cast_id': 7, 'character': 'Charles Dickens'...
# 18  [{'cast_id': 2, 'character': 'Kim Matthews', '...
# 19  [{'cast_id': 1, 'character': 'Frank Martin', '...
# 20  [{'cast_id': 26, 'character': 'Dr. Zachary Smi...
# 21  [{'cast_id': 1, 'character': 'Chris Higgins', ...
# 22  [{'cast_id': 1, 'character': 'Gary', 'credit_i...
# 23  [{'cast_id': 1037, 'character': 'Det. Canto', ...
# 24  [{'cast_id': 9, 'character': 'Henry Oldfield',...
# 25  [{'cast_id': 2, 'character': 'Dr. Evan Rendell...
# 26  [{'cast_id': 1, 'character': 'Jimmy Dell', 'cr...
# 27  [{'cast_id': 5, 'character': 'Wallace', 'credi...
# 28  [{'cast_id': 10, 'character': 'Hot Rod/Rodimus...
# 29  [{'cast_id': 1, 'character': 'Gavin Banek', 'c...
#
#                                                  crew    revenue
# 10  [{'credit_id': '579948e9c3a36874e9007b0b', 'de...  117235147
# 11  [{'credit_id': '52fe46f49251416c750891e9', 'de...   22642033
# 12  [{'credit_id': '52fe420ec3a36847f80007c5', 'de...  356296601
# 13  [{'credit_id': '52fe43cbc3a36847f807039f', 'de...   95226116
# 14  [{'credit_id': '52fe4223c3a36847f8006f3d', 'de...  358372926
# 15  [{'credit_id': '52fe4927c3a36847f818bb5f', 'de...        198
# 16  [{'credit_id': '52fe44449251416c7502eb99', 'de...   57891803
# 17  [{'credit_id': '53b94a260e0a2676c7009b37', 'de...    1234254
# 18  [{'credit_id': '52fe495ac3a36847f8195d4d', 'de...    1749457
# 19  [{'credit_id': '52fe44e9c3a36847f80b154d', 'de...   85167639
# 20  [{'credit_id': '52fe433bc3a36847f80448b9', 'de...  136159423
# 21  [{'credit_id': '52fe4523c3a36847f80be885', 'de...   36690067
# 22  [{'credit_id': '52fe48ee9251416c9109d113', 'de...     100345
# 23  [{'credit_id': '52fe4980c3a368484e12e993', 'de...      17011
# 24  [{'credit_id': '52fe43a0c3a36847f8063031', 'de...    4947717
# 25  [{'credit_id': '54b1fb3b925141144f000991', 'de...    8403433
# 26  [{'credit_id': '52fe45cfc3a368484e07017d', 'de...   13835130
# 27  [{'credit_id': '52fe4db4c3a368484e1f8003', 'de...    7847000
# 28  [{'credit_id': '52fe431bc3a36847f803ab1b', 'de...    5849647
# 29  [{'credit_id': '52fe42fbc3a36847f80317d5', 'de...   94935764
#
# [20 rows x 23 columns]

# %%
df['original_language']=='en'
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
english_movies=df[df['original_language']=='en']
english_movies.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
#
#   release_date runtime                          spoken_languages    status  \
# 0      2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2     10/10/14   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5       8/6/87    83.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6      8/30/12    92.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 5                                                NaN
# 6               Fear The Demon That Doesn't Fear God
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 5                                                NaN
# 6                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
#
# [5 rows x 23 columns]

# %%
english_movies.shape
# Out:
# (2575, 23)

# %%
long_movies=df[df['runtime']>120]
long_movies[['title']]
# Out:
#                     title
# 3                 Kahaani
# 12        American Beauty
# 14        Minority Report
# 20          Lost in Space
# 33        ABCs of Death 2
# ...                   ...
# 2969         Gosford Park
# 2970        The Bodyguard
# 2980     Action Hero Biju
# 2992  The Thief of Bagdad
# 2993         The Terminal
#
# [657 rows x 1 columns]

# %%
long_movies.tail()
# Out:
#         id belongs_to_collection    budget  \
# 2969  2970                   NaN  19800000
# 2970  2971                   NaN  25000000
# 2980  2981                   NaN    300000
# 2992  2993                   NaN   1135654
# 2993  2994                   NaN  60000000
#
#                                                  genres  \
# 2969  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 2970  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 2980  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                       homepage    imdb_id original_language  \
# 2969                                       NaN  tt0280707                en
# 2970                                       NaN  tt0103855                en
# 2980  https://www.facebook.com/Actionherobiju/  tt5320514                ml
# 2992                                       NaN  tt0015400                en
# 2993      http://www.theterminal-themovie.com/  tt0362227                en
#
#            original_title                                           overview  \
# 2969         Gosford Park  Multiple storylined drama set in 1932, showing...
# 2970        The Bodyguard  A former Secret Service agent grudgingly takes...
# 2980      ആക്ഷൻ ഹീറോ ബിജു  Biju is an honest policeman who fights the inj...
# 2992  The Thief of Bagdad  A recalcitrant thief vies with a duplicitous M...
# 2993         The Terminal  Viktor Navorski is a man without a country; hi...
#
#       popularity  ... release_date runtime  \
# 2969   14.101101  ...      11/7/01   137.0
# 2970    9.805017  ...     11/25/92   129.0
# 2980    0.350207  ...       2/4/16   144.0
# 2992    3.878515  ...      3/18/24   149.0
# 2993   14.092373  ...      6/17/04   128.0
#
#                                        spoken_languages    status  \
# 2969           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2970           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2980                  [{'iso_639_1': 'ml', 'name': ''}]  Released
# 2992       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 2993  [{'iso_639_1': 'bg', 'name': 'български език'}...  Released
#
#                                                 tagline                title  \
# 2969  Tea at four. Dinner at eight. Murder at midnight.         Gosford Park
# 2970  Never let her out of your sight. Never let you...        The Bodyguard
# 2980                       A ride with a police officer     Action Hero Biju
# 2992                         "Happiness Must Be Earned"  The Thief of Bagdad
# 2993                                   Life is waiting.         The Terminal
#
#                                                Keywords  \
# 2969  [{'id': 964, 'name': 'servant'}, {'id': 10594,...
# 2970  [{'id': 1156, 'name': 'sister sister relations...
# 2980  [{'id': 1252, 'name': 'suicide attempt'}, {'id...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
#
#                                                    cast  \
# 2969  [{'cast_id': 2, 'character': 'Mrs. Wilson', 'c...
# 2970  [{'cast_id': 17, 'character': 'Rachel Marron',...
# 2980  [{'cast_id': 1, 'character': 'Sub-Inspector Bi...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
#
#                                                    crew    revenue
# 2969  [{'credit_id': '52fe4401c3a36847f807ceab', 'de...   87754044
# 2970  [{'credit_id': '52fe425ec3a36847f8019133', 'de...  411006740
# 2980  [{'credit_id': '56b4d47f92514112b90045f6', 'de...    2500000
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...    1213880
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
#
# [5 rows x 23 columns]

# %%
(df['original_language']=='en') & (df['runtime']>120)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %%
long_english_movies=df[(df['original_language']=='en') & (df['runtime']>120)]
long_english_movies.head()
# Out:
#     id                              belongs_to_collection     budget  \
# 12  13                                                NaN   15000000
# 14  15                                                NaN  102000000
# 20  21                                                NaN   80000000
# 33  34  [{'id': 207632, 'name': 'The ABCs of Death Col...          0
# 37  38                                                NaN   50000000
#
#                                                genres  \
# 12                      [{'id': 18, 'name': 'Drama'}]
# 14  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 20  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 33                     [{'id': 27, 'name': 'Horror'}]
# 37  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                          homepage    imdb_id original_language  \
# 12  http://www.dreamworks.com/ab/  tt0169547                en
# 14                            NaN  tt0181689                en
# 20                            NaN  tt0120738                en
# 33                            NaN  tt2926810                en
# 37                            NaN  tt0114069                en
#
#      original_title                                           overview  \
# 12  American Beauty  Lester Burnham, a depressed suburban father in...
# 14  Minority Report  John Anderton is a top 'Precrime' cop in the l...
# 20    Lost in Space  The prospects for continuing life on Earth in ...
# 33  ABCs of Death 2  Taking all that was great from the first insta...
# 37         Outbreak  A deadly airborne virus finds its way into the...
#
#     popularity  ... release_date runtime  \
# 12   20.726578  ...      9/15/99   122.0
# 14   20.666063  ...      6/20/02   145.0
# 20   12.000579  ...       4/3/98   130.0
# 33    8.254856  ...      10/2/14   125.0
# 37   13.676444  ...      3/10/95   127.0
#
#                                      spoken_languages    status  \
# 12           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 20           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 33  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...  Released
# 37  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                               tagline            title  \
# 12                                       Look closer.  American Beauty
# 14    The system is perfect until it comes after you.  Minority Report
# 20                             Danger, Will Robinson!    Lost in Space
# 33                            Some people never learn  ABCs of Death 2
# 37  This animal carries a deadly virus... and the ...         Outbreak
#
#                                              Keywords  \
# 12  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 14  [{'id': 476, 'name': 'self-fulfilling prophecy...
# 20  [{'id': 4379, 'name': 'time travel'}, {'id': 1...
# 33  [{'id': 9706, 'name': 'anthology'}, {'id': 187...
# 37  [{'id': 1261, 'name': 'river'}, {'id': 1402, '...
#
#                                                  cast  \
# 12  [{'cast_id': 6, 'character': 'Lester Burnham',...
# 14  [{'cast_id': 5, 'character': 'Chief John Ander...
# 20  [{'cast_id': 26, 'character': 'Dr. Zachary Smi...
# 33  [{'cast_id': 60, 'character': 'Assassin (Segme...
# 37  [{'cast_id': 1, 'character': 'Sam Daniels', 'c...
#
#                                                  crew    revenue
# 12  [{'credit_id': '52fe420ec3a36847f80007c5', 'de...  356296601
# 14  [{'credit_id': '52fe4223c3a36847f8006f3d', 'de...  358372926
# 20  [{'credit_id': '52fe433bc3a36847f80448b9', 'de...  136159423
# 33  [{'credit_id': '52fe4cd69251416c91101d73', 'de...       7171
# 37  [{'credit_id': '52fe446ac3a36847f80949d3', 'de...  189859560
#
# [5 rows x 23 columns]

# %%
df[['runtime','cast']]
# Out:
#       runtime                                               cast
# 0        93.0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1       113.0  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2       105.0  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3       122.0  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4       118.0  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...       ...                                                ...
# 2995    102.0  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996    102.0  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997    120.0  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998     90.0  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999    106.0  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
# [3000 rows x 2 columns]

# %%
df['half_runtime']=df['runtime']*0.5
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ... runtime  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...    93.0
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...   113.0
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...   105.0
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...   122.0
# 4  Marine Boy is the story of a former national s...    1.148070  ...   118.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue half_runtime
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
# [5 rows x 24 columns]

# %%
df['movie_profit']=df['revenue']-df['budget']
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                                 production_companies  ... runtime  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...  ...    93.0
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]  ...   113.0
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...  ...   105.0
# 3                                                NaN  ...   122.0
# 4                                                NaN  ...   118.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue movie_profit
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651     -1685349
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435     55149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000      9792000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000     14800000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970      3923970
#
# [5 rows x 22 columns]

# %%
df.drop(['id'],axis=1,inplace=True)
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                         poster_path  ... release_date runtime  \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg  ...      2/20/15    93.0
# 1  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...       8/6/04   113.0
# 2  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...     10/10/14   105.0
# 3  /aTXRaPrWSinhcmCrcfJK17urp3F.jpg  ...       3/9/12   122.0
# 4  /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg  ...       2/5/09   118.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 22 columns]

# %%
df['budget'].sum()
# Out:
# 67594002330

# %%
df.iloc[:3]
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
#
#                         poster_path  ... release_date runtime  \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg  ...      2/20/15    93.0
# 1  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...       8/6/04   113.0
# 2  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...     10/10/14   105.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
#
# [3 rows x 22 columns]

# %%
df.set_index('budget',inplace=True)
df.head()
# Out:
#                                       belongs_to_collection  \
# budget
# 14000000  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 40000000  [{'id': 107674, 'name': 'The Princess Diaries ...
# 3300000                                                 NaN
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                                      genres  \
# budget
# 14000000                     [{'id': 35, 'name': 'Comedy'}]
# 40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3300000                       [{'id': 18, 'name': 'Drama'}]
# 1200000   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 0         [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                    homepage    imdb_id original_language  \
# budget
# 14000000                                NaN  tt2637294                en
# 40000000                                NaN  tt0368933                en
# 3300000   http://sonyclassics.com/whiplash/  tt2582802                en
# 1200000          http://kahaanithefilm.com/  tt1821480                hi
# 0                                       NaN  tt1380152                ko
#
#                                     original_title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
# 1200000                                    Kahaani
# 0                                             마린보이
#
#                                                    overview  popularity  \
# budget
# 14000000  When Lou, who has become the "father of the In...    6.575393
# 40000000  Mia Thermopolis is now a college graduate and ...    8.248895
# 3300000   Under the direction of a ruthless instructor, ...   64.299990
# 1200000   Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 0         Marine Boy is the story of a former national s...    1.148070
#
#                                poster_path  \
# budget
# 14000000  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg
# 40000000  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg
# 3300000   /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg
# 1200000   /aTXRaPrWSinhcmCrcfJK17urp3F.jpg
# 0         /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg
#
#                                        production_companies  ... release_date  \
# budget                                                       ...
# 14000000  [{'name': 'Paramount Pictures', 'id': 4}, {'na...  ...      2/20/15
# 40000000        [{'name': 'Walt Disney Pictures', 'id': 2}]  ...       8/6/04
# 3300000   [{'name': 'Bold Films', 'id': 2266}, {'name': ...  ...     10/10/14
# 1200000                                                 NaN  ...       3/9/12
# 0                                                       NaN  ...       2/5/09
#
#          runtime                                   spoken_languages    status  \
# budget
# 14000000    93.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 40000000   113.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3300000    105.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1200000    122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 0          118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                                     tagline  \
# budget
# 14000000  The Laws of Space and Time are About to be Vio...
# 40000000  It can take a lifetime to find true love; she'...
# 3300000     The road to greatness can take you to the edge.
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                              title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
# 1200000                                    Kahaani
# 0                                       Marine Boy
#
#                                                    Keywords  \
# budget
# 14000000  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 40000000  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 3300000   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 1200000   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 0                                                       NaN
#
#                                                        cast  \
# budget
# 14000000  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 40000000  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 3300000   [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 1200000   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 0         [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                        crew   revenue
# budget
# 14000000  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 40000000  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 3300000   [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 1200000   [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 0         [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 21 columns]

# %%
df.loc[1]
# Out:
#        belongs_to_collection  \
# budget
# 1                        NaN
# 1                        NaN
# 1                        NaN
# 1                        NaN
# 1                        NaN
#
#                                                    genres homepage    imdb_id  \
# budget
# 1       [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN  tt0376144
# 1       [{'id': 10749, 'name': 'Romance'}, {'id': 53, ...      NaN  tt0374271
# 1       [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      NaN  tt0027977
# 1                           [{'id': 18, 'name': 'Drama'}]      NaN  tt0048028
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN  tt0120836
#
#        original_language original_title  \
# budget
# 1                     ta          Saamy
# 1                     hi      Tere Naam
# 1                     en   Modern Times
# 1                     en   East of Eden
# 1                     en   Lost & Found
#
#                                                  overview  popularity  \
# budget
# 1       Saamy movie is all about Arusaamy (Vikram) who...    0.438490
# 1       Lower Caste Radhey Mohan is a no good slacker,...    1.280455
# 1       The Tramp struggles to live in modern industri...    8.159556
# 1       In the Salinas Valley, in and around World War...    6.428830
# 1       A comedy about finding your true love at any p...    1.337096
#
#                              poster_path  \
# budget
# 1       /dIiEngfIy3G4ZP6CuhyuZa36mNW.jpg
# 1       /xNH5HVOc6U7qMPh9pbUWJxzROZm.jpg
# 1       /m4ZCx2Iwr418IGPxRfoKnpumz9X.jpg
# 1       /hjH1uLOySpzgBdm1UQYjTV5yLav.jpg
# 1       /jaylLo7TsJrJriNVGf72Asen1Fr.jpg
#
#                                      production_companies  ... release_date  \
# budget                                                     ...
# 1                                                     NaN  ...       5/5/03
# 1            [{'name': 'People Tree Films', 'id': 11791}]  ...      8/15/03
# 1       [{'name': 'United Artists', 'id': 60}, {'name'...  ...       2/5/36
# 1                  [{'name': 'Warner Bros.', 'id': 6194}]  ...       3/9/55
# 1       [{'name': 'Alcon Entertainment', 'id': 1088}, ...  ...      4/23/99
#
#        runtime                          spoken_languages    status  \
# budget
# 1        140.0    [{'iso_639_1': 'ta', 'name': 'தமிழ்'}]  Released
# 1        132.0   [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]  Released
# 1         87.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1        115.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1         95.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                   tagline         title  \
# budget
# 1                                                     NaN         Saamy
# 1                         Unfortunately a true love story     Tere Naam
# 1       He stands alone as the greatest entertainer of...  Modern Times
# 1       Of what a girl did . . . what a boy did ... of...  East of Eden
# 1       A comedy about a guy who would do anything to ...  Lost & Found
#
#                                                  Keywords  \
# budget
# 1                                                     NaN
# 1                                                     NaN
# 1       [{'id': 1382, 'name': 'factory'}, {'id': 1546,...
# 1       [{'id': 30, 'name': 'individual'}, {'id': 380,...
# 1       [{'id': 1946, 'name': 'restaurant'}, {'id': 10...
#
#                                                      cast  \
# budget
# 1       [{'cast_id': 11, 'character': 'Aaruchamy', 'cr...
# 1       [{'cast_id': 3, 'character': 'Radhe Mohan', 'c...
# 1       [{'cast_id': 8, 'character': 'A factory worker...
# 1       [{'cast_id': 4, 'character': 'Caleb Trask', 'c...
# 1       [{'cast_id': 1, 'character': 'Dylan Ramsey', '...
#
#                                                      crew  revenue
# budget
# 1       [{'credit_id': '52fe4782c3a36847f813999f', 'de...        3
# 1       [{'credit_id': '52fe491ec3a36847f8189cfb', 'de...        2
# 1       [{'credit_id': '5621aeadc3a3680e1d00a09a', 'de...  8500000
# 1       [{'credit_id': '52fe4228c3a36847f800869d', 'de...        5
# 1       [{'credit_id': '52fe47429251416c9106f659', 'de...      100
#
# [5 rows x 21 columns]

# %%
print(f"The shortest movie length is {df['runtime'].min()}")
print(f"The longest movie length is {df['runtime'].max()}")
# Out:
# The shortest movie length is 0.0
# The longest movie length is 338.0

# %%
# Apply Method
def to_uppercase(column):
  return column.upper()
df['Capitalized_Title']=df['title'].apply(to_uppercase)
df.head()
# Out:
#                                       belongs_to_collection  \
# budget
# 14000000  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 40000000  [{'id': 107674, 'name': 'The Princess Diaries ...
# 3300000                                                 NaN
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                                      genres  \
# budget
# 14000000                     [{'id': 35, 'name': 'Comedy'}]
# 40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3300000                       [{'id': 18, 'name': 'Drama'}]
# 1200000   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 0         [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                    homepage    imdb_id original_language  \
# budget
# 14000000                                NaN  tt2637294                en
# 40000000                                NaN  tt0368933                en
# 3300000   http://sonyclassics.com/whiplash/  tt2582802                en
# 1200000          http://kahaanithefilm.com/  tt1821480                hi
# 0                                       NaN  tt1380152                ko
#
#                                     original_title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
# 1200000                                    Kahaani
# 0                                             마린보이
#
#                                                    overview  popularity  \
# budget
# 14000000  When Lou, who has become the "father of the In...    6.575393
# 40000000  Mia Thermopolis is now a college graduate and ...    8.248895
# 3300000   Under the direction of a ruthless instructor, ...   64.299990
# 1200000   Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 0         Marine Boy is the story of a former national s...    1.148070
#
#                                poster_path  \
# budget
# 14000000  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg
# 40000000  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg
# 3300000   /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg
# 1200000   /aTXRaPrWSinhcmCrcfJK17urp3F.jpg
# 0         /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg
#
#                                        production_companies  ... runtime  \
# budget                                                       ...
# 14000000  [{'name': 'Paramount Pictures', 'id': 4}, {'na...  ...    93.0
# 40000000        [{'name': 'Walt Disney Pictures', 'id': 2}]  ...   113.0
# 3300000   [{'name': 'Bold Films', 'id': 2266}, {'name': ...  ...   105.0
# 1200000                                                 NaN  ...   122.0
# 0                                                       NaN  ...   118.0
#
#                                            spoken_languages    status  \
# budget
# 14000000           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 40000000           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3300000            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1200000   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 0                  [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                                     tagline  \
# budget
# 14000000  The Laws of Space and Time are About to be Vio...
# 40000000  It can take a lifetime to find true love; she'...
# 3300000     The road to greatness can take you to the edge.
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                              title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
# 1200000                                    Kahaani
# 0                                       Marine Boy
#
#                                                    Keywords  \
# budget
# 14000000  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 40000000  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 3300000   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 1200000   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 0                                                       NaN
#
#                                                        cast  \
# budget
# 14000000  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 40000000  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 3300000   [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 1200000   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 0         [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                        crew   revenue  \
# budget
# 14000000  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 40000000  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 3300000   [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 1200000   [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 0         [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
#                                  Capitalized_Title
# budget
# 14000000                    HOT TUB TIME MACHINE 2
# 40000000  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 3300000                                   WHIPLASH
# 1200000                                    KAHAANI
# 0                                       MARINE BOY
#
# [5 rows x 22 columns]
